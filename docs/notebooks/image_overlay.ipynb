# %% [markdown]
# # Image Overlay Example
#
# This notebook demonstrates the planned API for adding georeferenced image overlays to a map.
#
# **Note:** The `add_image_layer` method is not yet fully implemented. The frontend handler needs to be added to support this feature.

# %% [markdown]
# ## Planned API (Not Yet Implemented)
#
# Once frontend support is added, the API will work as shown below. Currently, calling `add_image_layer()` will raise `NotImplementedError`.

# %%
# This demonstrates the planned API. Currently raises NotImplementedError.
# Uncomment the code below once frontend support is added.

from anymap_ts import Map

m = Map(center=[-75.0, 42.0], zoom=5)

# Planned usage:
# m.add_image_layer(
#     url="https://docs.mapbox.com/mapbox-gl-js/assets/radar.gif",
#     coordinates=[
#         [-80.425, 46.437],  # top-left
#         [-71.516, 46.437],  # top-right
#         [-71.516, 37.936],  # bottom-right
#         [-80.425, 37.936],  # bottom-left
#     ],
#     opacity=0.8,
# )

m

# %% [markdown]
# ## Implementation Notes
#
# To add image overlay support, the MapLibre frontend needs to implement an `addImageLayer` handler that:
#
# 1. Adds an image source: `map.addSource(id, {type: 'image', url: '...', coordinates: [...]})`
# 2. Adds a raster layer referencing that source: `map.addLayer({id: id, type: 'raster', source: id})`
#
# Contributions welcome!
