# %% [markdown]
# # Image Overlay Example
#
# This notebook demonstrates how to add georeferenced image overlays to a map.

# %% [markdown]
# ## Basic Image Overlay

# %%
from anymap_ts import Map

m = Map(center=[-75.0, 42.0], zoom=5)

# Add an image overlay with corner coordinates
# Coordinates are: top-left, top-right, bottom-right, bottom-left
m.add_image_layer(
    url="https://docs.mapbox.com/mapbox-gl-js/assets/radar.gif",
    coordinates=[
        [-80.425, 46.437],  # top-left
        [-71.516, 46.437],  # top-right  
        [-71.516, 37.936],  # bottom-right
        [-80.425, 37.936],  # bottom-left
    ],
    opacity=0.8
)
m

# %% [markdown]
# ## Image Overlay with Transparency

# %%
m2 = Map(center=[-75.0, 42.0], zoom=5)

m2.add_image_layer(
    url="https://docs.mapbox.com/mapbox-gl-js/assets/radar.gif",
    coordinates=[
        [-80.425, 46.437],
        [-71.516, 46.437],
        [-71.516, 37.936],
        [-80.425, 37.936],
    ],
    opacity=0.5,
    name="radar-transparent"
)
m2

# %% [markdown]
# ## Export to HTML

# %%
m.to_html("image_overlay_example.html")
