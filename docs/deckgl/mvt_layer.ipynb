# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/anymap-ts/blob/main/docs/deckgl/mvt_layer.ipynb)
# [![Open in Notebook.link](https://img.shields.io/badge/notebook-link-e2d610?logo=jupyter&logoColor=white)](https://notebook.link/github/opengeos/anymap-ts/tree/main/lab/?path=docs/deckgl/mvt_layer.ipynb)

# %% [markdown]
# # MVT Layer Example
#
# Mapbox Vector Tiles rendering using deck.gl MVTLayer.

# %%
# %pip install anymap-ts

# %%
from anymap_ts import DeckGLMap

# %% [markdown]
# ## Create a map with MVT layer

# %%
m = DeckGLMap(center=[-122.4, 37.8], zoom=11)
m.add_basemap("CartoDB.DarkMatter")

# Add CARTO vector tiles
m.add_mvt_layer(
    data="https://tiles.basemaps.cartocdn.com/vectortiles/carto.streets/v1/{z}/{x}/{y}.mvt",
    min_zoom=0,
    max_zoom=14,
    get_line_color=[255, 255, 255, 200],
    get_fill_color=[100, 130, 180, 100],
    get_line_width=1,
    line_width_min_pixels=1,
    pickable=True,
)
m

# %% [markdown]
# ## Export to HTML

# %%
m.to_html("mvt_layer_example.html")
