# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/anymap-ts/blob/main/docs/maplibre/solara.ipynb)
# [![Open in Notebook.link](https://img.shields.io/badge/notebook-link-e2d610?logo=jupyter&logoColor=white)](https://notebook.link/github/opengeos/anymap-ts/tree/main/lab/?path=docs/maplibre/solara.ipynb)

# %% [markdown]
# # Solara Example
#
# This example demonstrates how to use Solara to create a simple map.

# %%
# %pip install -U anymap-ts solara

# %%
import solara
from anymap_ts import MapLibreMap


class Map(MapLibreMap):
    def __init__(self, **kwargs):
        super().__init__(
            center=[-117.592133766, 47.653004], zoom=15.3, height="700px", *kwargs
        )
        super().add_basemap("Esri.WorldImagery")


@solara.component
def Page():
    Map().element()


Page()
