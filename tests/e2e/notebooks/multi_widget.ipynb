# %%
from anymap_ts import Map

m = Map(center=[-122.4, 37.8], zoom=10, height="400px", controls={})
m

# %%
from anymap_ts import LeafletMap

lm = LeafletMap(center=[-122.4, 37.8], zoom=10, height="400px", controls={})
lm
