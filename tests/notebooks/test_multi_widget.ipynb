# %% [markdown]
# # Multi-Widget Instantiation Tests
#
# Verify that all supported widget types can be instantiated without errors.

# %%
from anymap_ts import DeckGLMap

dm = DeckGLMap(height="300px", controls={})
assert dm.center == [0.0, 0.0]
dm

# %%
from anymap_ts import OpenLayersMap

om = OpenLayersMap(height="300px", controls={})
assert om.center == [0.0, 0.0]
om

# %%
from anymap_ts import CesiumMap

cm = CesiumMap(height="300px", controls={})
assert cm.center == [0.0, 0.0]
cm

# %%
from anymap_ts import KeplerGLMap

km = KeplerGLMap(height="300px", controls={})
assert km.center == [0.0, 0.0]
km

# %%
from anymap_ts import PotreeViewer

pv = PotreeViewer(height="300px", controls={})
assert pv.center == [0.0, 0.0]
pv
